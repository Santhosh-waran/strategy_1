# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# data  = yf.download("EURUSD=X", "1999-01-04")
# data.to_csv("EURUSD.CSV")

# %%
data = pd.read_csv("EURUSD_CLOSE.csv", index_col=0, parse_dates=True)
data
# Out:
#                Close
# Date
# 2003-12-01  1.196501
# 2003-12-02  1.208897
# 2003-12-03  1.212298
# 2003-12-04  1.208094
# 2003-12-05  1.218695
# ...              ...
# 2024-10-28  1.079657
# 2024-10-29  1.081677
# 2024-10-30  1.082064
# 2024-10-31  1.085918
# 2024-11-01  1.086720
#
# [5431 rows x 1 columns]

# %%
# data.info()
# data.describe()
data.shape

# data = data.Close.to_frame().copy()
# data.to_csv("EURUSD_CLOSE.csv")
# Out:
# (5431, 1)

# %%
data["sma_50"] = data.Close.rolling(50).mean()
data["sma_100"] = data.Close.rolling(100).mean()
data["sma_200"] = data.Close.rolling(200).mean()

# %%
data.dropna().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='Date'>
