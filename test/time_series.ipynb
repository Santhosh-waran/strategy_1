# %%
import yfinance as yf
import pandas as  pd

ticker = 'RELIANCE.NS'
# data = yf.download(ticker,start='2019-01-01', end='2024-6-6',interval='1D')
data = pd.read_csv("D_RELIANCE.csv", parse_dates=["Date"])#, index_col=0)
# data.to_csv("D_RELIANCE.CSV")
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-01-01   514.426453   515.363647   507.500366   512.483459
# 1    2019-01-02   509.511902   515.226501   503.340149   505.808868
# 2    2019-01-03   506.311737   509.557617   498.357056   499.568542
# 3    2019-01-04   501.694366   504.917389   494.242554   502.265808
# 4    2019-01-07   506.083160   511.317719   503.340149   505.054535
# ...         ...          ...          ...          ...          ...
# 1334 2024-05-30  1435.500000  1440.400024  1420.099976  1424.849976
# 1335 2024-05-31  1431.300049  1442.250000  1422.250000  1430.400024
# 1336 2024-06-03  1483.000000  1514.500000  1459.000000  1510.324951
# 1337 2024-06-04  1498.050049  1498.050049  1359.300049  1397.275024
# 1338 2024-06-05  1422.000000  1431.150024  1384.099976  1420.750000
#
#         Adj Close    Volume
# 0      490.444550   9746670
# 1      484.056946  15628818
# 2      478.084991  16288287
# 3      480.666321  18516544
# ...

# %%
# data.dropna().Close.plot(figsize=(15,8))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1339 entries, 2019-01-01 to 2024-06-05
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1339 non-null   float64
#  1   High       1339 non-null   float64
#  2   Low        1339 non-null   float64
#  3   Close      1339 non-null   float64
#  4   Adj Close  1339 non-null   float64
#  5   Volume     1339 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 73.2 KB

# %%
data.iloc[0,0]
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  514.426453  515.363647  507.500366  512.483459  490.444550
# 2019-01-02  509.511902  515.226501  503.340149  505.808868  484.056946
# 2019-01-03  506.311737  509.557617  498.357056  499.568542  478.084991
# 2019-01-04  501.694366  504.917389  494.242554  502.265808  480.666321
# 2019-01-07  506.083160  511.317719  503.340149  505.054535  483.335114
#
#               Volume
# Date
# 2019-01-01   9746670
# 2019-01-02  15628818
# 2019-01-03  16288287
# 2019-01-04  18516544
# 2019-01-07  12060290

# %%
print("ok") if data.loc["2023-01" : "2023-12"].equals(data.loc["2023"]) else print("failed")
data.loc["2023-01" : "2023-12"].equals(data.loc["2023"])
# Out:
# ok
# True

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-30  1435.500000  1440.400024  1420.099976  1424.849976  1415.210815
# 2024-05-31  1431.300049  1442.250000  1422.250000  1430.400024  1420.723389
# 2024-06-03  1483.000000  1514.500000  1459.000000  1510.324951  1500.107544
# 2024-06-04  1498.050049  1498.050049  1359.300049  1397.275024  1387.822388
# 2024-06-05  1422.000000  1431.150024  1384.099976  1420.750000  1411.138672
#
#               Volume
# Date
# 2024-05-30  13206858
# 2024-05-31  31069832
# 2024-06-03  21527942
# 2024-06-04  36709098
# 2024-06-05  17464890

# %%
import pandas as pd
import matplotlib as plt
plt.style.use("seaborn-v0_8")

# %%
list(data.resample("ME"))[2]
# Out:
# (Timestamp('2019-03-31 00:00:00'),
#                    Open        High         Low       Close   Adj Close  \
#  Date
#  2019-03-01  565.514771  567.960632  558.771606  560.508789  536.404541
#  2019-03-05  559.297302  566.794861  557.102905  565.811951  541.479736
#  2019-03-06  566.794861  582.018494  564.646179  578.223999  553.357910
#  2019-03-07  577.858276  585.081482  575.183838  580.715576  555.742371
#  2019-03-08  578.795471  582.635681  576.943970  579.275513  554.364258
#  2019-03-11  580.624146  599.802246  579.686951  596.190674  570.552002
#  2019-03-12  602.042358  609.859924  600.830872  608.648438  582.473938
#  2019-03-13  611.231445  621.746216  607.162659  615.940247  589.452271
#  2019-03-14  617.060303  622.660583  610.819946  613.311523  586.936584
#  2019-03-15  614.888733  621.197632  599.436523  604.213928  578.230164
#  2019-03-18  608.488403  620.809082  607.574097  617.197449  590.655457
# ...
